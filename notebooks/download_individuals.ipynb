# %%
import json
import os
from io import BytesIO

import eyed3
import ffmpeg
import requests
from yt_dlp import YoutubeDL

# %%
from yt_dlp import YoutubeDL

songs = []


def download_youtube_audio(urls):
    options = {
        "listformats": True,
        "ignoreerrors": True,
        "cookiefile": "./outputs/cookies.txt",
    }

    with YoutubeDL(options) as ydl:
        for url in urls:
            info = ydl.extract_info(url)
            songs.append(info)


youtube_urls = [
    "https://music.youtube.com/watch?v=TdYcD7lsVF0&si=wRtOVbaRJLOYCpwq",
    "https://music.youtube.com/watch?v=2oul7U3nNtE&si=36hJY4rHiyk3Py55",
    "https://music.youtube.com/watch?v=t9ndxDhgZBM&si=YGnd2iXWlOGWcTgN",
    "https://music.youtube.com/watch?v=qwMrQSXatZc&si=ZlJdqNU2H1iG8Nkg",
    "https://music.youtube.com/watch?v=lI45tU5rvP0&si=9iHcplEo7MgF-Xy2",
    "https://music.youtube.com/watch?v=z7rxl5KsPjs&si=Z16BFBPsU8x7isUH",
    
]


# Download the YouTube audio
download_youtube_audio(youtube_urls)
# Out:
# [youtube] Extracting URL: https://music.youtube.com/watch?v=TdYcD7lsVF0&si=wRtOVbaRJLOYCpwq
# [youtube] TdYcD7lsVF0: Downloading webpage
# [youtube] TdYcD7lsVF0: Downloading ios player API JSON
# [youtube] TdYcD7lsVF0: Downloading mweb player API JSON
# [youtube] TdYcD7lsVF0: Downloading ios music player API JSON
# [youtube] TdYcD7lsVF0: Downloading web music client config
# [youtube] TdYcD7lsVF0: Downloading player 03dbdfab
# [youtube] TdYcD7lsVF0: Downloading web music player API JSON
# WARNING: [youtube] TdYcD7lsVF0: Signature extraction failed: Some formats may be missing
# [youtube] TdYcD7lsVF0: Downloading m3u8 information
# [info] Available formats for TdYcD7lsVF0:
# ID  EXT   RESOLUTION FPS CH |   FILESIZE   TBR PROTO | VCODEC          VBR ACODEC      ABR ASR MORE INFO
# ----------------------------------------------------------------------------------------------------------------
# sb2 mhtml 48x27        1    |                  mhtml | images                                  storyboard
# sb1 mhtml 45x45        1    |                  mhtml | images                                  storyboard
# sb0 mhtml 90x90        1    |                  mhtml | images                                  storyboard
# 233 mp4   audio only        |                  m3u8  | audio only          unknown             Default
# 234 mp4   audio only        |                  m3u8  | audio only          unknown             Default
# 139 m4a   audio only      2 |    1.03MiB   49k https | audio only          mp4a.40.5   49k 22k low, m4a_dash
# 249 webm  audio only      2 |    1.09MiB   52k https | audio only          opus        52k 48k low, webm_dash
# 250 webm  audio only      2 |    1.44MiB   69k https | audio only          opus        69k 48k low, webm_dash
# 140 m4a   audio only      2 |    2.72MiB  130k https | audio only          mp4a.40.2  130k 44k medium, m4a_dash
# 251 webm  audio only      2 |    2.81MiB  134k https | audio only          opus       134k 48k medium, webm_dash
# 269 mp4   144x144     25    | ~  2.08MiB   99k m3u8  | avc1.4D400B     99k video only
# 160 mp4   144x144     25    |  633.71KiB   29k https | avc1.4D400B     29k video only          144p, mp4_dash
# 603 mp4   144x144     25    | ~  1.95MiB   93k m3u8  | vp09.00.11.08   93k video only
# 278 webm  144x144     25    |  494.20KiB   23k https | vp09.00.11.08   23k video only          144p, webm_dash
# 229 mp4   240x240     25    | ~  3.34MiB  159k m3u8  | avc1.4D400C    159k video only
# 133 mp4   240x240     25    |    1.31MiB   62k https | avc1.4D400C     62k video only          240p, mp4_dash
# 604 mp4   240x240     25    | ~  2.97MiB  142k m3u8  | vp09.00.20.08  142k video only
# 242 webm  240x240     25    |  934.30KiB   43k https | vp09.00.20.08   43k video only          240p, webm_dash
# 230 mp4   360x360     25    | ~  4.39MiB  209k m3u8  | avc1.4D4015    209k video only
# 134 mp4   360x360     25    |  690.66KiB   32k https | avc1.4D4015     32k video only          360p, mp4_dash
# 605 mp4   360x360     25    | ~  6.44MiB  307k m3u8  | vp09.00.21.08  307k video only
# 243 webm  360x360     25    |    1.48MiB   70k https | vp09.00.21.08   70k video only          360p, webm_dash
# 231 mp4   480x480     25    | ~  5.38MiB  257k m3u8  | avc1.4D401E    257k video only
# 135 mp4   480x480     25    |    1.08MiB   51k https | avc1.4D401E     51k video only          480p, mp4_dash
# 606 mp4   480x480     25    | ~  8.81MiB  420k m3u8  | vp09.00.30.08  420k video only
# 244 webm  480x480     25    |    2.43MiB  116k https | vp09.00.30.08  116k video only          480p, webm_dash
# 232 mp4   720x720     25    | ~  7.48MiB  356k m3u8  | avc1.4D401F    356k video only
# 136 mp4   720x720     25    |    1.98MiB   94k https | avc1.4D401F     94k video only          720p, mp4_dash
# 609 mp4   720x720     25    | ~ 15.37MiB  732k m3u8  | vp09.00.31.08  732k video only
# 247 webm  720x720     25    |    5.10MiB  243k https | vp09.00.31.08  243k video only          720p, webm_dash
# 270 mp4   1080x1080   25    | ~ 12.20MiB  582k m3u8  | avc1.640020    582k video only
# 137 mp4   1080x1080   25    |    3.94MiB  188k https | avc1.640020    188k video only          1080p, mp4_dash
# 614 mp4   1080x1080   25    | ~ 23.62MiB 1126k m3u8  | vp09.00.40.08 1126k video only
# 248 webm  1080x1080   25    |   10.38MiB  494k https | vp09.00.40.08  494k video only          1080p, webm_dash
# [youtube] Extracting URL: https://music.youtube.com/watch?v=2oul7U3nNtE&si=36hJY4rHiyk3Py55
# [youtube] 2oul7U3nNtE: Downloading webpage
# [youtube] 2oul7U3nNtE: Downloading ios player API JSON
# [youtube] 2oul7U3nNtE: Downloading mweb player API JSON
# [youtube] 2oul7U3nNtE: Downloading ios music player API JSON
# [youtube] 2oul7U3nNtE: Downloading web music client config
# [youtube] 2oul7U3nNtE: Downloading web music player API JSON
# WARNING: [youtube] 2oul7U3nNtE: Signature extraction failed: Some formats may be missing
# [youtube] 2oul7U3nNtE: Downloading m3u8 information
# [info] Available formats for 2oul7U3nNtE:
# ID  EXT   RESOLUTION FPS CH |  FILESIZE   TBR PROTO | VCODEC          VBR ACODEC      ABR ASR MORE INFO
# ---------------------------------------------------------------------------------------------------------------
# sb2 mhtml 48x27        0    |                 mhtml | images                                  storyboard
# sb1 mhtml 45x45        0    |                 mhtml | images                                  storyboard
# sb0 mhtml 90x90        0    |                 mhtml | images                                  storyboard
# 233 mp4   audio only        |                 m3u8  | audio only          unknown             Default
# 234 mp4   audio only        |                 m3u8  | audio only          unknown             Default
# 139 m4a   audio only      2 |   3.41MiB   49k https | audio only          mp4a.40.5   49k 22k low, m4a_dash
# 249 webm  audio only      2 |   3.67MiB   53k https | audio only          opus        53k 48k low, webm_dash
# 250 webm  audio only      2 |   4.85MiB   69k https | audio only          opus        69k 48k low, webm_dash
# 140 m4a   audio only      2 |   9.06MiB  130k https | audio only          mp4a.40.2  130k 44k medium, m4a_dash
# 251 webm  audio only      2 |   9.43MiB  135k https | audio only          opus       135k 48k medium, webm_dash
# 269 mp4   144x144     25    | ~ 7.03MiB  100k m3u8  | avc1.4D400B    100k video only
# 160 mp4   144x144     25    |   2.22MiB   32k https | avc1.4D400B     32k video only          144p, mp4_dash
# 603 mp4   144x144     25    | ~ 6.15MiB   88k m3u8  | vp09.00.11.08   88k video only
# 278 webm  144x144     25    |   1.63MiB   23k https | vp09.00.11.08   23k video only          144p, webm_dash
# 229 mp4   240x240     25    | ~11.28MiB  161k m3u8  | avc1.4D400C    161k video only
# 133 mp4   240x240     25    |   4.75MiB   68k https | avc1.4D400C     68k video only          240p, mp4_dash
# 604 mp4   240x240     25    | ~ 9.12MiB  130k m3u8  | vp09.00.20.08  130k video only
# 242 webm  240x240     25    |   2.95MiB   42k https | vp09.00.20.08   42k video only          240p, webm_dash
# 230 mp4   360x360     25    | ~13.41MiB  192k m3u8  | avc1.4D4015    192k video only
# 134 mp4   360x360     25    |   2.14MiB   31k https | avc1.4D4015     31k video only          360p, mp4_dash
# 605 mp4   360x360     25    | ~17.95MiB  256k m3u8  | vp09.00.21.08  256k video only
# 243 webm  360x360     25    |   4.47MiB   64k https | vp09.00.21.08   64k video only          360p, webm_dash
# 231 mp4   480x480     25    | ~15.77MiB  225k m3u8  | avc1.4D401E    225k video only
# 135 mp4   480x480     25    |   3.41MiB   49k https | avc1.4D401E     49k video only          480p, mp4_dash
# 606 mp4   480x480     25    | ~23.12MiB  330k m3u8  | vp09.00.30.08  330k video only
# 244 webm  480x480     25    |   7.19MiB  103k https | vp09.00.30.08  103k video only          480p, webm_dash
# 232 mp4   720x720     25    | ~20.48MiB  293k m3u8  | avc1.4D401F    293k video only
# 136 mp4   720x720     25    |   6.06MiB   87k https | avc1.4D401F     87k video only          720p, mp4_dash
# 609 mp4   720x720     25    | ~38.46MiB  550k m3u8  | vp09.00.31.08  550k video only
# 247 webm  720x720     25    |  15.28MiB  219k https | vp09.00.31.08  219k video only          720p, webm_dash
# 270 mp4   1080x1080   25    | ~30.06MiB  430k m3u8  | avc1.640020    430k video only
# 137 mp4   1080x1080   25    |  11.59MiB  166k https | avc1.640020    166k video only          1080p, mp4_dash
# 614 mp4   1080x1080   25    | ~71.05MiB 1015k m3u8  | vp09.00.40.08 1015k video only
# 248 webm  1080x1080   25    |  32.31MiB  462k https | vp09.00.40.08  462k video only          1080p, webm_dash
# [youtube] Extracting URL: https://music.youtube.com/watch?v=t9ndxDhgZBM&si=YGnd2iXWlOGWcTgN
# [youtube] t9ndxDhgZBM: Downloading webpage
# [youtube] t9ndxDhgZBM: Downloading ios player API JSON
# [youtube] t9ndxDhgZBM: Downloading mweb player API JSON
# [youtube] t9ndxDhgZBM: Downloading ios music player API JSON
# [youtube] t9ndxDhgZBM: Downloading web music client config
# [youtube] t9ndxDhgZBM: Downloading web music player API JSON
# WARNING: [youtube] t9ndxDhgZBM: Signature extraction failed: Some formats may be missing
# [youtube] t9ndxDhgZBM: Downloading m3u8 information
# [info] Available formats for t9ndxDhgZBM:
# ID  EXT   RESOLUTION FPS CH |  FILESIZE  TBR PROTO | VCODEC         VBR ACODEC      ABR ASR MORE INFO
# -------------------------------------------------------------------------------------------------------------
# sb2 mhtml 48x27        0    |                mhtml | images                                 storyboard
# sb1 mhtml 45x45        0    |                mhtml | images                                 storyboard
# sb0 mhtml 90x90        0    |                mhtml | images                                 storyboard
# 233 mp4   audio only        |                m3u8  | audio only         unknown             Default
# 234 mp4   audio only        |                m3u8  | audio only         unknown             Default
# 139 m4a   audio only      2 |   2.28MiB  49k https | audio only         mp4a.40.5   49k 22k low, m4a_dash
# 249 webm  audio only      2 |   2.62MiB  56k https | audio only         opus        56k 48k low, webm_dash
# 250 webm  audio only      2 |   3.43MiB  73k https | audio only         opus        73k 48k low, webm_dash
# 140 m4a   audio only      2 |   6.04MiB 130k https | audio only         mp4a.40.2  130k 44k medium, m4a_dash
# 251 webm  audio only      2 |   6.61MiB 142k https | audio only         opus       142k 48k medium, webm_dash
# 269 mp4   146x144     25    | ~ 4.99MiB 107k m3u8  | avc1.4D400B   107k video only
# 160 mp4   146x144     25    |   1.64MiB  35k https | avc1.4D400B    35k video only          144p, mp4_dash
# 603 mp4   146x144     25    | ~ 4.05MiB  87k m3u8  | vp09.00.11.08  87k video only
# 278 webm  146x144     25    |   1.13MiB  24k https | vp09.00.11.08  24k video only          144p, webm_dash
# 229 mp4   242x240     25    | ~ 8.09MiB 174k m3u8  | avc1.4D400C   174k video only
# 133 mp4   242x240     25    |   3.65MiB  78k https | avc1.4D400C    78k video only          240p, mp4_dash
# 604 mp4   242x240     25    | ~ 6.61MiB 142k m3u8  | vp09.00.20.08 142k video only
# 242 webm  242x240     25    |   2.27MiB  49k https | vp09.00.20.08  49k video only          240p, webm_dash
# 230 mp4   362x360     25    | ~10.53MiB 226k m3u8  | avc1.4D4015   226k video only
# 134 mp4   362x360     25    |   1.87MiB  40k https | avc1.4D4015    40k video only          360p, mp4_dash
# 605 mp4   362x360     25    | ~14.03MiB 301k m3u8  | vp09.00.21.08 301k video only
# 243 webm  362x360     25    |   4.53MiB  97k https | vp09.00.21.08  97k video only          360p, webm_dash
# 231 mp4   484x480     25    | ~14.19MiB 304k m3u8  | avc1.4D401E   304k video only
# 135 mp4   484x480     25    |   3.47MiB  74k https | avc1.4D401E    74k video only          480p, mp4_dash
# 606 mp4   484x480     25    | ~19.87MiB 426k m3u8  | vp09.00.30.08 426k video only
# 244 webm  484x480     25    |   7.92MiB 170k https | vp09.00.30.08 170k video only          480p, webm_dash
# 232 mp4   726x720     25    | ~21.45MiB 460k m3u8  | avc1.4D401F   460k video only
# 136 mp4   726x720     25    |   6.64MiB 142k https | avc1.4D401F   142k video only          720p, mp4_dash
# 609 mp4   726x720     25    | ~32.51MiB 698k m3u8  | vp09.00.31.08 698k video only
# 247 webm  726x720     25    |  16.88MiB 362k https | vp09.00.31.08 362k video only          720p, webm_dash
# [youtube] Extracting URL: https://music.youtube.com/watch?v=qwMrQSXatZc&si=ZlJdqNU2H1iG8Nkg
# [youtube] qwMrQSXatZc: Downloading webpage
# [youtube] qwMrQSXatZc: Downloading ios player API JSON
# [youtube] qwMrQSXatZc: Downloading mweb player API JSON
# [youtube] qwMrQSXatZc: Downloading ios music player API JSON
# [youtube] qwMrQSXatZc: Downloading web music client config
# [youtube] qwMrQSXatZc: Downloading web music player API JSON
# WARNING: [youtube] qwMrQSXatZc: Signature extraction failed: Some formats may be missing
# [youtube] qwMrQSXatZc: Downloading m3u8 information
# [info] Available formats for qwMrQSXatZc:
# ID  EXT   RESOLUTION FPS CH |   FILESIZE  TBR PROTO | VCODEC         VBR ACODEC      ABR ASR MORE INFO
# --------------------------------------------------------------------------------------------------------------
# sb2 mhtml 48x27        0    |                 mhtml | images                                 storyboard
# sb1 mhtml 45x45        1    |                 mhtml | images                                 storyboard
# sb0 mhtml 90x90        1    |                 mhtml | images                                 storyboard
# 233 mp4   audio only        |                 m3u8  | audio only         unknown             Default
# 234 mp4   audio only        |                 m3u8  | audio only         unknown             Default
# 139 m4a   audio only      2 |    1.74MiB  49k https | audio only         mp4a.40.5   49k 22k low, m4a_dash
# 249 webm  audio only      2 |    1.94MiB  54k https | audio only         opus        54k 48k low, webm_dash
# 250 webm  audio only      2 |    2.59MiB  73k https | audio only         opus        73k 48k low, webm_dash
# 140 m4a   audio only      2 |    4.62MiB 130k https | audio only         mp4a.40.2  130k 44k medium, m4a_dash
# 251 webm  audio only      2 |    4.99MiB 140k https | audio only         opus       140k 48k medium, webm_dash
# 269 mp4   146x144     25    | ~  3.64MiB 102k m3u8  | avc1.4D400B   102k video only
# 160 mp4   146x144     25    |  937.08KiB  26k https | avc1.4D400B    26k video only          144p, mp4_dash
# 603 mp4   146x144     25    | ~  3.18MiB  89k m3u8  | vp09.00.11.08  89k video only
# 278 webm  146x144     25    |  699.87KiB  19k https | vp09.00.11.08  19k video only          144p, webm_dash
# 229 mp4   242x240     25    | ~  5.39MiB 151k m3u8  | avc1.4D400C   151k video only
# 133 mp4   242x240     25    |    1.65MiB  46k https | avc1.4D400C    46k video only          240p, mp4_dash
# 604 mp4   242x240     25    | ~  4.27MiB 120k m3u8  | vp09.00.20.08 120k video only
# 242 webm  242x240     25    |    1.10MiB  31k https | vp09.00.20.08  31k video only          240p, webm_dash
# 230 mp4   362x360     25    | ~  6.78MiB 190k m3u8  | avc1.4D4015   190k video only
# 134 mp4   362x360     25    |  842.54KiB  23k https | avc1.4D4015    23k video only          360p, mp4_dash
# 605 mp4   362x360     25    | ~  8.79MiB 247k m3u8  | vp09.00.21.08 247k video only
# 243 webm  362x360     25    |    1.58MiB  44k https | vp09.00.21.08  44k video only          360p, webm_dash
# 231 mp4   484x480     25    | ~  7.91MiB 222k m3u8  | avc1.4D401E   222k video only
# 135 mp4   484x480     25    |    1.29MiB  36k https | avc1.4D401E    36k video only          480p, mp4_dash
# 606 mp4   484x480     25    | ~ 10.71MiB 300k m3u8  | vp09.00.30.08 300k video only
# 244 webm  484x480     25    |    2.35MiB  66k https | vp09.00.30.08  66k video only          480p, webm_dash
# 232 mp4   726x720     25    | ~  9.52MiB 267k m3u8  | avc1.4D401F   267k video only
# 136 mp4   726x720     25    |    1.94MiB  54k https | avc1.4D401F    54k video only          720p, mp4_dash
# 609 mp4   726x720     25    | ~ 14.51MiB 407k m3u8  | vp09.00.31.08 407k video only
# 247 webm  726x720     25    |    3.84MiB 108k https | vp09.00.31.08 108k video only          720p, webm_dash
# [youtube] Extracting URL: https://music.youtube.com/watch?v=lI45tU5rvP0&si=9iHcplEo7MgF-Xy2
# [youtube] lI45tU5rvP0: Downloading webpage
# [youtube] lI45tU5rvP0: Downloading ios player API JSON
# [youtube] lI45tU5rvP0: Downloading mweb player API JSON
# [youtube] lI45tU5rvP0: Downloading ios music player API JSON
# [youtube] lI45tU5rvP0: Downloading web music client config
# [youtube] lI45tU5rvP0: Downloading web music player API JSON
# WARNING: [youtube] lI45tU5rvP0: Signature extraction failed: Some formats may be missing
# [youtube] lI45tU5rvP0: Downloading m3u8 information
# [info] Available formats for lI45tU5rvP0:
# ID  EXT   RESOLUTION FPS CH |    FILESIZE  TBR PROTO | VCODEC         VBR ACODEC      ABR ASR MORE INFO
# ---------------------------------------------------------------------------------------------------------------
# sb3 mhtml 48x27        0    |                  mhtml | images                                 storyboard
# sb2 mhtml 45x45        1    |                  mhtml | images                                 storyboard
# sb1 mhtml 90x90        1    |                  mhtml | images                                 storyboard
# sb0 mhtml 180x180      1    |                  mhtml | images                                 storyboard
# 233 mp4   audio only        |                  m3u8  | audio only         unknown             Default
# 234 mp4   audio only        |                  m3u8  | audio only         unknown             Default
# 139 m4a   audio only      2 |     1.30MiB  49k https | audio only         mp4a.40.5   49k 22k low, m4a_dash
# 249 webm  audio only      2 |     1.37MiB  51k https | audio only         opus        51k 48k low, webm_dash
# 250 webm  audio only      2 |     1.82MiB  68k https | audio only         opus        68k 48k low, webm_dash
# 140 m4a   audio only      2 |     3.44MiB 130k https | audio only         mp4a.40.2  130k 44k medium, m4a_dash
# 251 webm  audio only      2 |     3.56MiB 134k https | audio only         opus       134k 48k medium, webm_dash
# 602 mp4   144x144     13    | ~   2.21MiB  83k m3u8  | vp09.00.10.08  83k video only
# 269 mp4   144x144     25    | ~   2.44MiB  92k m3u8  | avc1.4D400B    92k video only
# 160 mp4   144x144     25    |   537.21KiB  20k https | avc1.4D400B    20k video only          144p, mp4_dash
# 603 mp4   144x144     25    | ~   2.54MiB  96k m3u8  | vp09.00.11.08  96k video only
# 278 webm  144x144     25    |   662.60KiB  24k https | vp09.00.11.08  24k video only          144p, webm_dash
# 229 mp4   240x240     25    | ~   3.62MiB 136k m3u8  | avc1.4D400C   136k video only
# 133 mp4   240x240     25    |  1004.61KiB  37k https | avc1.4D400C    37k video only          240p, mp4_dash
# 604 mp4   240x240     25    | ~   3.75MiB 141k m3u8  | vp09.00.20.08 141k video only
# 242 webm  240x240     25    |     1.17MiB  44k https | vp09.00.20.08  44k video only          240p, webm_dash
# 230 mp4   360x360     25    | ~   6.92MiB 260k m3u8  | avc1.4D4015   260k video only
# 134 mp4   360x360     25    |     1.60MiB  60k https | avc1.4D4015    60k video only          360p, mp4_dash
# 605 mp4   360x360     25    | ~   7.14MiB 269k m3u8  | vp09.00.21.08 269k video only
# 243 webm  360x360     25    |     1.66MiB  63k https | vp09.00.21.08  63k video only          360p, webm_dash
# 231 mp4   480x480     25    | ~   9.19MiB 346k m3u8  | avc1.4D401E   346k video only
# 135 mp4   480x480     25    |     2.72MiB 102k https | avc1.4D401E   102k video only          480p, mp4_dash
# 606 mp4   480x480     25    | ~   8.99MiB 338k m3u8  | vp09.00.30.08 338k video only
# 244 webm  480x480     25    |     2.62MiB  99k https | vp09.00.30.08  99k video only          480p, webm_dash
# 232 mp4   720x720     25    | ~  10.57MiB 398k m3u8  | avc1.64001F   398k video only
# 136 mp4   720x720     25    |     3.77MiB 142k https | avc1.64001F   142k video only          720p, mp4_dash
# 609 mp4   720x720     25    | ~  13.91MiB 523k m3u8  | vp09.00.31.08 523k video only
# 247 webm  720x720     25    |     5.37MiB 202k https | vp09.00.31.08 202k video only          720p, webm_dash
# 270 mp4   1080x1080   25    | ~  16.76MiB 631k m3u8  | avc1.640020   631k video only
# 137 mp4   1080x1080   25    |     7.18MiB 270k https | avc1.640020   270k video only          1080p, mp4_dash
# 614 mp4   1080x1080   25    | ~  26.18MiB 985k m3u8  | vp09.00.40.08 985k video only
# 248 webm  1080x1080   25    |    10.37MiB 391k https | vp09.00.40.08 391k video only          1080p, webm_dash
# [youtube] Extracting URL: https://music.youtube.com/watch?v=z7rxl5KsPjs&si=Z16BFBPsU8x7isUH
# [youtube] z7rxl5KsPjs: Downloading webpage
# [youtube] z7rxl5KsPjs: Downloading ios player API JSON
# [youtube] z7rxl5KsPjs: Downloading mweb player API JSON
# [youtube] z7rxl5KsPjs: Downloading ios music player API JSON
# [youtube] z7rxl5KsPjs: Downloading web music client config
# [youtube] z7rxl5KsPjs: Downloading web music player API JSON
# WARNING: [youtube] z7rxl5KsPjs: Signature extraction failed: Some formats may be missing
# [youtube] z7rxl5KsPjs: Downloading m3u8 information
# [info] Available formats for z7rxl5KsPjs:
# ID  EXT   RESOLUTION FPS CH |  FILESIZE  TBR PROTO | VCODEC         VBR ACODEC      ABR ASR MORE INFO
# -------------------------------------------------------------------------------------------------------------
# sb3 mhtml 48x27        0    |                mhtml | images                                 storyboard
# sb2 mhtml 60x45        0    |                mhtml | images                                 storyboard
# sb1 mhtml 120x90       0    |                mhtml | images                                 storyboard
# sb0 mhtml 240x180      0    |                mhtml | images                                 storyboard
# 233 mp4   audio only        |                m3u8  | audio only         unknown             Default
# 234 mp4   audio only        |                m3u8  | audio only         unknown             Default
# 139 m4a   audio only      2 |   5.76MiB  49k https | audio only         mp4a.40.5   49k 22k low, m4a_dash
# 249 webm  audio only      2 |   6.51MiB  55k https | audio only         opus        55k 48k low, webm_dash
# 250 webm  audio only      2 |   8.58MiB  73k https | audio only         opus        73k 48k low, webm_dash
# 140 m4a   audio only      2 |  15.28MiB 129k https | audio only         mp4a.40.2  129k 44k medium, m4a_dash
# 251 webm  audio only      2 |  16.53MiB 140k https | audio only         opus       140k 48k medium, webm_dash
# 602 mp4   192x144     13    | ~ 9.02MiB  76k m3u8  | vp09.00.10.08  76k video only
# 269 mp4   192x144     25    | ~ 8.92MiB  76k m3u8  | avc1.4D400B    76k video only
# 160 mp4   192x144     25    |   1.06MiB   9k https | avc1.4D400B     9k video only          144p, mp4_dash
# 603 mp4   192x144     25    | ~13.44MiB 114k m3u8  | vp09.00.11.08 114k video only
# 278 webm  192x144     25    |   2.07MiB  18k https | vp09.00.11.08  18k video only          144p, webm_dash
# 394 mp4   192x144     25    |   2.31MiB  20k https | av01.0.00M.08  20k video only          144p, mp4_dash
# 229 mp4   320x240     25    | ~10.30MiB  87k m3u8  | avc1.4D400D    87k video only
# 133 mp4   320x240     25    |   1.57MiB  13k https | avc1.4D400D    13k video only          240p, mp4_dash
# 604 mp4   320x240     25    | ~16.81MiB 142k m3u8  | vp09.00.20.08 142k video only
# 242 webm  320x240     25    |   2.60MiB  22k https | vp09.00.20.08  22k video only          240p, webm_dash
# 395 mp4   320x240     25    |   5.21MiB  44k https | av01.0.00M.08  44k video only          240p, mp4_dash
# 230 mp4   480x360     25    | ~22.10MiB 187k m3u8  | avc1.4D4015   187k video only
# 134 mp4   480x360     25    |   2.40MiB  20k https | avc1.4D4015    20k video only          360p, mp4_dash
# 605 mp4   480x360     25    | ~34.98MiB 296k m3u8  | vp09.00.21.08 296k video only
# 243 webm  480x360     25    |   9.67MiB  82k https | vp09.00.21.08  82k video only          360p, webm_dash
# 396 mp4   480x360     25    |   7.89MiB  67k https | av01.0.01M.08  67k video only          360p, mp4_dash
# 231 mp4   640x480     25    | ~24.73MiB 210k m3u8  | avc1.4D401E   210k video only
# 135 mp4   640x480     25    |   3.37MiB  29k https | avc1.4D401E    29k video only          480p, mp4_dash
# 606 mp4   640x480     25    | ~43.68MiB 370k m3u8  | vp09.00.30.08 370k video only
# 244 webm  640x480     25    |  11.86MiB 101k https | vp09.00.30.08 101k video only          480p, webm_dash
# 397 mp4   640x480     25    |  12.22MiB 104k https | av01.0.04M.08 104k video only          480p, mp4_dash

# %%
options = {
    # "listformats": True,
    "cookiefile": "./outputs/cookies.txt",
    "outtmpl": "./outputs/downloads/%(title)s.%(ext)s",  # Output file name
}

for i, entry in enumerate(songs):
    if not entry:
        print(f"{i + 1}. None")
        continue

    formats = [f for f in entry["formats"] if f["resolution"] == "audio only"]
    formats.sort(key=lambda x: x["tbr"] or 0, reverse=True)
    format_id = formats[0]["format_id"]

    title = entry["title"]
    title = title.replace("｜", "|")
    title = title.replace("：", ":")
    title = title.replace("＂", "\"",)
    title = title.replace("/", "-")
    
    output_file = "./outputs/downloads/" + title + "." + formats[0]["audio_ext"]
    options["outtmpl"] = output_file
    
    if os.path.exists(output_file):
        print(f"{i + 1}. {entry['title']} - EXISTED")
        continue
    print(f"{i + 1}. {entry['title']}")

    options["format"] = format_id
    with YoutubeDL(options) as ydl:
        ydl.download(entry["original_url"])

print("Download completed!")
# Out:
# 1. Keyboard Concerto No. 5 in F Minor, BWV 1056: II. Largo
# [youtube] Extracting URL: https://music.youtube.com/watch?v=TdYcD7lsVF0&si=wRtOVbaRJLOYCpwq
# [youtube] TdYcD7lsVF0: Downloading webpage
# [youtube] TdYcD7lsVF0: Downloading ios player API JSON
# [youtube] TdYcD7lsVF0: Downloading mweb player API JSON
# [youtube] TdYcD7lsVF0: Downloading ios music player API JSON
# [youtube] TdYcD7lsVF0: Downloading web music client config
# [youtube] TdYcD7lsVF0: Downloading player 03dbdfab
# [youtube] TdYcD7lsVF0: Downloading web music player API JSON
# WARNING: [youtube] TdYcD7lsVF0: Signature extraction failed: Some formats may be missing
# [youtube] TdYcD7lsVF0: Downloading m3u8 information
# [info] TdYcD7lsVF0: Downloading 1 format(s): 251
# [download] Destination: ./outputs/downloads/Keyboard Concerto No. 5 in F Minor, BWV 1056: II. Largo.webm
# [download] 100% of    2.81MiB in 00:00:00 at 6.74MiB/s
# 2. Ponchielli: La Gioconda, Op. 9 / Act 3 - Dance of the Hours
# [youtube] Extracting URL: https://music.youtube.com/watch?v=2oul7U3nNtE&si=36hJY4rHiyk3Py55
# [youtube] 2oul7U3nNtE: Downloading webpage
# [youtube] 2oul7U3nNtE: Downloading ios player API JSON
# [youtube] 2oul7U3nNtE: Downloading mweb player API JSON
# [youtube] 2oul7U3nNtE: Downloading ios music player API JSON
# [youtube] 2oul7U3nNtE: Downloading web music client config
# [youtube] 2oul7U3nNtE: Downloading player 03dbdfab
# [youtube] 2oul7U3nNtE: Downloading web music player API JSON
# WARNING: [youtube] 2oul7U3nNtE: Signature extraction failed: Some formats may be missing
# [youtube] 2oul7U3nNtE: Downloading m3u8 information
# [info] 2oul7U3nNtE: Downloading 1 format(s): 251
# [download] Destination: ./outputs/downloads/Ponchielli: La Gioconda, Op. 9 - Act 3 - Dance of the Hours.webm
# [download] 100% of    9.43MiB in 00:00:00 at 17.96MiB/s
# 3. Brahms: Symphony No. 3 in F Major, Op. 90 - III. Poco allegretto
# [youtube] Extracting URL: https://music.youtube.com/watch?v=t9ndxDhgZBM&si=YGnd2iXWlOGWcTgN
# [youtube] t9ndxDhgZBM: Downloading webpage
# [youtube] t9ndxDhgZBM: Downloading ios player API JSON
# [youtube] t9ndxDhgZBM: Downloading mweb player API JSON
# [youtube] t9ndxDhgZBM: Downloading ios music player API JSON
# [youtube] t9ndxDhgZBM: Downloading web music client config
# [youtube] t9ndxDhgZBM: Downloading player 03dbdfab
# [youtube] t9ndxDhgZBM: Downloading web music player API JSON
# WARNING: [youtube] t9ndxDhgZBM: Signature extraction failed: Some formats may be missing
# [youtube] t9ndxDhgZBM: Downloading m3u8 information
# [info] t9ndxDhgZBM: Downloading 1 format(s): 251
# [download] Destination: ./outputs/downloads/Brahms: Symphony No. 3 in F Major, Op. 90 - III. Poco allegretto.webm
# [download] 100% of    6.61MiB in 00:00:00 at 12.24MiB/s
# 4. Schubert: Symphony No. 3 in D, D.200: 2. Allegretto
# [youtube] Extracting URL: https://music.youtube.com/watch?v=qwMrQSXatZc&si=ZlJdqNU2H1iG8Nkg
# [youtube] qwMrQSXatZc: Downloading webpage
# [youtube] qwMrQSXatZc: Downloading ios player API JSON
# [youtube] qwMrQSXatZc: Downloading mweb player API JSON
# [youtube] qwMrQSXatZc: Downloading ios music player API JSON
# [youtube] qwMrQSXatZc: Downloading web music client config
# [youtube] qwMrQSXatZc: Downloading player 03dbdfab
# [youtube] qwMrQSXatZc: Downloading web music player API JSON
# WARNING: [youtube] qwMrQSXatZc: Signature extraction failed: Some formats may be missing
# [youtube] qwMrQSXatZc: Downloading m3u8 information
# [info] qwMrQSXatZc: Downloading 1 format(s): 251
# [download] Destination: ./outputs/downloads/Schubert: Symphony No. 3 in D, D.200: 2. Allegretto.webm
# [download] 100% of    4.99MiB in 00:00:00 at 8.94MiB/s
# 5. The Second Waltz, Op. 99a - EXISTED
# 6. Tartini Violin Sonata in G minor ''Devil's Trill Sonata'' - EXISTED
# Download completed!

# %%
not_exists = []
for i, entry in enumerate(songs):
    if not entry:
        print(f"{i + 1}. None")
        continue

    formats = [f for f in entry["formats"] if f["resolution"] == "audio only"]
    formats.sort(key=lambda x: x["tbr"] or 0, reverse=True)
    format_id = formats[0]["format_id"]

    title = entry["title"]
    title = title.replace("｜", "|")
    title = title.replace("：", ":")
    title = title.replace("＂", "\"",)
    title = title.replace("/", "-")

    fulltitle = entry["fulltitle"]
    fulltitle = fulltitle.replace("｜", "|")
    fulltitle = fulltitle.replace("：", ":")
    fulltitle = fulltitle.replace("＂", "\"",)
    fulltitle = fulltitle.replace("/", "-")

    webm = "./outputs/downloads/" + title + "." + formats[0]["audio_ext"]
    mp3 = "./outputs/thumbnails/" + fulltitle + "." + "mp3"
    # webm = webm.replace("|", "｜")
    # webm = webm.replace(":", "：")
    # webm = webm.replace("\"", "＂")
    # webm = webm.replace("/", "⧸")
    
    
    if not os.path.exists(webm):
        not_exists.append(webm)
        print("Not existed - ", webm)
        continue
    if os.path.exists(mp3):
        print("Existed - ", mp3)
        continue

    ffmpeg.input(webm).output(mp3, vn=None, acodec="libmp3lame", q=0).run()

    audiofile = eyed3.load(mp3)
    img_data = requests.get(entry["thumbnail"]).content
    audiofile.tag.images.set(3, img_data, "image/jpeg")
    audiofile.tag.artist = entry.get("artist", None)
    audiofile.tag.album = entry.get("album", None)
    audiofile.tag.title = entry.get("fulltitle", None)

    audiofile.tag.save()

    print(f"Thumbnail added to {mp3}")
# Out:
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 13.3.0 (conda-forge gcc 13.3.0-1)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --disable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --enable-librsvg --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, matroska,webm, from './outputs/downloads/Keyboard Concerto No. 5 in F Minor, BWV 1056: II. Largo.webm':
#   Metadata:
#     encoder         : google/video-file
#   Duration: 00:02:56.22, start: -0.007000, bitrate: 133 kb/s
#   Stream #0:0(eng): Audio: opus, 48000 Hz, stereo, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to './outputs/thumbnails/Keyboard Concerto No. 5 in F Minor, BWV 1056: II. Largo.mp3':
#   Metadata:
#     TSSE            : Lavf61.7.100
#   Stream #0:0(eng): Audio: mp3, 48000 Hz, stereo, fltp (default)
#       Metadata:
#         encoder         : Lavc61.19.100 libmp3lame
# [out#0/mp3 @ 0x55e4f0ccd640] video:0KiB audio:5007KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.004603% 113x    size=    4608KiB time=00:02:48.55 bitrate= 223.9kbits/s speed= 112x
# size=    5007KiB time=00:02:56.22 bitrate= 232.8kbits/s speed= 112x
# Thumbnail added to ./outputs/thumbnails/Keyboard Concerto No. 5 in F Minor, BWV 1056: II. Largo.mp3
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 13.3.0 (conda-forge gcc 13.3.0-1)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --disable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --enable-librsvg --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, matroska,webm, from './outputs/downloads/Ponchielli: La Gioconda, Op. 9 - Act 3 - Dance of the Hours.webm':
#   Metadata:
#     encoder         : google/video-file
#   Duration: 00:09:46.52, start: -0.007000, bitrate: 134 kb/s
#   Stream #0:0(eng): Audio: opus, 48000 Hz, stereo, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to './outputs/thumbnails/Ponchielli: La Gioconda, Op. 9 - Act 3 - Dance of the Hours.mp3':
#   Metadata:
#     TSSE            : Lavf61.7.100
#   Stream #0:0(eng): Audio: mp3, 48000 Hz, stereo, fltp (default)
#       Metadata:
#         encoder         : Lavc61.19.100 libmp3lame
# [out#0/mp3 @ 0x564bbcb99bc0] video:0KiB audio:17322KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.001331%108x    size=    4608KiB time=00:02:40.83 bitrate= 234.7kbits/s speed= 107x    size=    6144KiB time=00:03:33.70 bitrate= 235.5kbits/s speed= 107x    size=    7680KiB time=00:04:26.43 bitrate= 236.1kbits/s speed= 107x    size=    9216KiB time=00:05:20.67 bitrate= 235.4kbits/s speed= 107x    size=   10752KiB time=00:06:14.09 bitrate= 235.4kbits/s speed= 107x    size=   12288KiB time=00:07:06.87 bitrate= 235.8kbits/s speed= 107x    size=   13824KiB time=00:07:58.01 bitrate= 236.9kbits/s speed= 106x    size=   15360KiB time=00:08:50.09 bitrate= 237.4kbits/s speed= 106x    size=   17152KiB time=00:09:40.80 bitrate= 241.9kbits/s speed= 106x
# size=   17322KiB time=00:09:46.51 bitrate= 241.9kbits/s speed= 106x
# Thumbnail added to ./outputs/thumbnails/Ponchielli: La Gioconda, Op. 9 - Act 3 - Dance of the Hours.mp3
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 13.3.0 (conda-forge gcc 13.3.0-1)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --disable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --enable-librsvg --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, matroska,webm, from './outputs/downloads/Brahms: Symphony No. 3 in F Major, Op. 90 - III. Poco allegretto.webm':
#   Metadata:
#     encoder         : google/video-file
#   Duration: 00:06:31.42, start: -0.007000, bitrate: 141 kb/s
#   Stream #0:0(eng): Audio: opus, 48000 Hz, stereo, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to './outputs/thumbnails/Brahms: Symphony No. 3 in F Major, Op. 90 - III. Poco allegretto.mp3':
#   Metadata:
#     TSSE            : Lavf61.7.100
#   Stream #0:0(eng): Audio: mp3, 48000 Hz, stereo, fltp (default)
#       Metadata:
#         encoder         : Lavc61.19.100 libmp3lame
# [out#0/mp3 @ 0x5560c1211040] video:0KiB audio:11408KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.002020%107x    size=    4608KiB time=00:02:41.74 bitrate= 233.4kbits/s speed= 108x    size=    6144KiB time=00:03:35.28 bitrate= 233.8kbits/s speed= 108x    size=    7680KiB time=00:04:28.47 bitrate= 234.3kbits/s speed= 107x    size=    9216KiB time=00:05:21.63 bitrate= 234.7kbits/s speed= 107x    size=   10752KiB time=00:06:13.59 bitrate= 235.8kbits/s speed= 107x
# size=   11408KiB time=00:06:31.40 bitrate= 238.8kbits/s speed= 107x
# Thumbnail added to ./outputs/thumbnails/Brahms: Symphony No. 3 in F Major, Op. 90 - III. Poco allegretto.mp3
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 13.3.0 (conda-forge gcc 13.3.0-1)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --disable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --enable-librsvg --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, matroska,webm, from './outputs/downloads/Schubert: Symphony No. 3 in D, D.200: 2. Allegretto.webm':
#   Metadata:
#     encoder         : google/video-file
#   Duration: 00:04:59.02, start: -0.007000, bitrate: 139 kb/s
#   Stream #0:0(eng): Audio: opus, 48000 Hz, stereo, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to './outputs/thumbnails/Schubert: Symphony No. 3 in D, D.200: 2. Allegretto.mp3':
#   Metadata:
#     TSSE            : Lavf61.7.100
#   Stream #0:0(eng): Audio: mp3, 48000 Hz, stereo, fltp (default)
#       Metadata:
#         encoder         : Lavc61.19.100 libmp3lame
# size=    1280KiB time=00:00:50.81 bitrate= 206.3kbits/s speed= 102x    size=    2816KiB time=00:01:43.66 bitrate= 222.5kbits/s speed= 104x    size=    4352KiB time=00:02:35.67 bitrate= 229.0kbits/s speed= 104x    size=    5888KiB time=00:03:26.38 bitrate= 233.7kbits/s speed= 103x    size=    7424KiB time=00:04:17.02 bitrate= 236.6kbits/s speed= 103x    [out#0/mp3 @ 0x56259b88e6c0] video:0KiB audio:8652KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.002664%
# size=    8652KiB time=00:04:59.00 bitrate= 237.0kbits/s speed= 103x
# Thumbnail added to ./outputs/thumbnails/Schubert: Symphony No. 3 in D, D.200: 2. Allegretto.mp3
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 13.3.0 (conda-forge gcc 13.3.0-1)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --disable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --enable-librsvg --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, matroska,webm, from './outputs/downloads/The Second Waltz, Op. 99a.webm':
#   Metadata:
#     encoder         : google/video-file
#   Duration: 00:03:42.60, start: -0.007000, bitrate: 134 kb/s
#   Stream #0:0(eng): Audio: opus, 48000 Hz, stereo, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to './outputs/thumbnails/The Second Waltz, Op. 99a.mp3':
#   Metadata:
#     TSSE            : Lavf61.7.100
#   Stream #0:0(eng): Audio: mp3, 48000 Hz, stereo, fltp (default)
#       Metadata:
#         encoder         : Lavc61.19.100 libmp3lame
# size=    1536KiB time=00:00:52.71 bitrate= 238.7kbits/s speed= 105x    size=    3072KiB time=00:01:40.90 bitrate= 249.4kbits/s speed= 101x    size=    4608KiB time=00:02:28.15 bitrate= 254.8kbits/s speed=98.7x    size=    6144KiB time=00:03:17.45 bitrate= 254.9kbits/s speed=98.7x    [out#0/mp3 @ 0x55607fb08c80] video:0KiB audio:7043KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.003272%
# size=    7043KiB time=00:03:42.59 bitrate= 259.2kbits/s speed=92.7x
# Thumbnail added to ./outputs/thumbnails/The Second Waltz, Op. 99a.mp3
# ffmpeg version 7.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 13.3.0 (conda-forge gcc 13.3.0-1)
#   configuration: --prefix=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_h_env_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_placehold_plac --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_build_env/bin/x86_64-conda-linux-gnu-cc --cxx=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_build_env/bin/x86_64-conda-linux-gnu-c++ --nm=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_build_env/bin/x86_64-conda-linux-gnu-nm --ar=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_build_env/bin/x86_64-conda-linux-gnu-ar --disable-doc --enable-openssl --enable-demuxer=dash --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libopenh264 --enable-libdav1d --disable-gnutls --enable-libmp3lame --enable-libvpx --enable-libass --enable-pthreads --enable-vaapi --enable-libopenvino --enable-gpl --enable-libx264 --enable-libx265 --enable-libaom --enable-libsvtav1 --enable-libxml2 --enable-pic --enable-shared --disable-static --enable-version3 --enable-zlib --enable-libopus --enable-librsvg --pkg-config=/home/conda/feedstock_root/build_artifacts/ffmpeg_1732155191655/_build_env/bin/pkg-config
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.100 / 61. 19.100
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, matroska,webm, from './outputs/downloads/Tartini Violin Sonata in G minor ''Devil's Trill Sonata''.webm':
#   Metadata:
#     encoder         : google/video-file
#   Duration: 00:16:30.10, start: -0.007000, bitrate: 140 kb/s
#   Stream #0:0(eng): Audio: opus, 48000 Hz, stereo, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to './outputs/thumbnails/Tartini Violin Sonata in G minor ''Devil's Trill Sonata''.mp3':
#   Metadata:
#     TSSE            : Lavf61.7.100
#   Stream #0:0(eng): Audio: mp3, 48000 Hz, stereo, fltp (default)
#       Metadata:
#         encoder         : Lavc61.19.100 libmp3lame
# [out#0/mp3 @ 0x5563caa7b040] video:0KiB audio:27124KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.000850%119x    size=    4352KiB time=00:02:55.13 bitrate= 203.6kbits/s speed= 117x    size=    5888KiB time=00:03:50.71 bitrate= 209.1kbits/s speed= 115x    size=    7424KiB time=00:04:44.64 bitrate= 213.7kbits/s speed= 114x    size=    8960KiB time=00:05:37.08 bitrate= 217.7kbits/s speed= 112x    size=   10240KiB time=00:06:28.25 bitrate= 216.1kbits/s speed= 111x    size=   11776KiB time=00:07:20.21 bitrate= 219.1kbits/s speed= 110x    size=   13312KiB time=00:08:13.90 bitrate= 220.8kbits/s speed= 110x    size=   14848KiB time=00:09:08.59 bitrate= 221.7kbits/s speed= 110x    size=   16384KiB time=00:10:01.11 bitrate= 223.3kbits/s speed= 109x    size=   17664KiB time=00:10:55.63 bitrate= 220.7kbits/s speed= 109x    size=   19200KiB time=00:11:49.01 bitrate= 221.8kbits/s speed= 109x    size=   20736KiB time=00:12:44.35 bitrate= 222.2kbits/s speed= 109x    size=   22016KiB time=00:13:36.84 bitrate= 220.8kbits/s speed= 109x    size=   23552KiB time=00:14:29.79 bitrate= 221.8kbits/s speed= 109x    size=   25088KiB time=00:15:22.03 bitrate= 222.9kbits/s speed= 108x    size=   26624KiB time=00:16:13.47 bitrate= 224.0kbits/s speed= 108x
# size=   27124KiB time=00:16:30.08 bitrate= 224.4kbits/s speed= 108x
# Thumbnail added to ./outputs/thumbnails/Tartini Violin Sonata in G minor ''Devil's Trill Sonata''.mp3
